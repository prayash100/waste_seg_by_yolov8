# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Thu Jan 23 17:55:20 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8              13W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME=os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.4/911.4 kB 30.8 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.1/112.6 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.11.11
# Install             pip
# RAM                 12.67 GB
# Disk                31.1/112.6 GB
# CPU                 Intel Xeon 2.00GHz
# CPU count           2
# GPU                 Tesla T4, 15102MiB
# GPU count           1
# CUDA                12.1
#
# numpy               ✅ 1.26.4>=1.23.0
# numpy               ✅ 1.26.4<2.0.0; sys_platform == "darwin"
# matplotlib          ✅ 3.10.0>=3.3.0
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="68O3OR824hEs2cHe9V0x")
project = rf.workspace("workpro").project("trash-sorting-037nw-lagms-e4kfs-tfess-4vlxz")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to trash-sorting-1 in yolov8:: 100%|██████████| 4266/4266 [00:00<00:00, 4508.19it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=70 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 79.0MB/s]
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import display, Image

# %%
# !ls {HOME}/runs/detect/train
# Out:
# args.yaml					    R_curve.png		 val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 val_batch1_labels.jpg
# events.out.tfevents.1737654986.e09fdbc30641.1246.0  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					    train_batch1.jpg	 val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch2.jpg	 val_batch2_pred.jpg
# labels.jpg					    train_batch5040.jpg  weights
# P_curve.png					    train_batch5041.jpg
# PR_curve.png					    train_batch5042.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/F1_curve.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/PR_curve.png', width=800)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix_normalized.png', width=800)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=800)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/train_batch1.jpg', width=800)
# Out:
# /content

# %%
# %cd
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /root
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/trash-sorting-1/valid/labels.cache... 463 images, 3 backgrounds, 0 corrupt: 100% 463/463 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/trash-sorting-1/valid/images/63971668873496397166887351_frame3_jpg.rf.2cdaed64e50e66656908cdde651d1db4.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/trash-sorting-1/valid/images/63f22a2944e6163f22a2944e62_frame44_jpg.rf.eddb57990ac860d98f0ef9e76663e135.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/trash-sorting-1/valid/images/63f22a2944e6163f22a2944e62_frame58_jpg.rf.2e82b7d2aba07fa2530a3616ac5ce4f4.jpg: 1 duplicate labels removed
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 29/29 [00:07<00:00,  4.08it/s]
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/train/weights/best.pt')
files.download('/content/runs/detect/train/weights/last.pt')

# %%
import shutil
import os

# Define the paths of the folders you want to exclude
source_dir = '/content'  # Replace with your source directory if different
exclude_folders = ['/content/trash-sorting-1', '/content/drive']  # Folders to exclude

# Temporary directory for zipping without the excluded folders
temp_dir = '/content/temp'

# Create the temp directory if it doesn't exist
os.makedirs(temp_dir, exist_ok=True)

# Loop through the source directory and copy everything except the excluded folders and `.gdoc` files
for foldername in os.listdir(source_dir):
    folder_path = os.path.join(source_dir, foldername)
    if folder_path not in exclude_folders:
        if os.path.isdir(folder_path):
            shutil.copytree(folder_path, os.path.join(temp_dir, foldername), ignore=shutil.ignore_patterns('*.gdoc'))
        elif not folder_path.endswith('.gdoc'):  # Skip `.gdoc` files
            shutil.copy(folder_path, temp_dir)

# Create a zip of the new directory
shutil.make_archive('/content/downloaded_files', 'zip', temp_dir)

# Download the zip file
from google.colab import files
files.download('/content/downloaded_files.zip')

# %%
# !pip install pickle-mixin
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle-mixin: filename=pickle_mixin-1.0.2-py3-none-any.whl size=5990 sha256=9a07f1293735b51913ec0d649f094bb87a158f2f8ea508567d66eb0bb24240d5
#   Stored in directory: /root/.cache/pip/wheels/d0/9c/0d/8709be17c02b72bf04ea60d8ec64fc46a1554c0fb81e048dd6
# Successfully built pickle-mixin
# ...

# %%
import pickle

# Load the trained weights
weights_path = '/content/runs/detect/train/weights/best.pt'  # Replace with your actual path
# Load and convert the weights to a pickle file
with open(weights_path, 'rb') as f:
    weights = f.read()
pickle.dump(weights, open('yolo.pkl', 'wb'))

# %%
from google.colab import files
files.download('yolo.pkl')

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/IMG_4868.JPG
# Out:
# /content
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/IMG_4868.JPG: 640x480 1 Glass, 70.4ms
# Speed: 5.3ms preprocess, 70.4ms inference, 905.8ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/000006.jpg
# Out:
# /content
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/000006.jpg: 640x480 1 Glass, 36.3ms
# Speed: 3.2ms preprocess, 36.3ms inference, 516.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/000035.jpg
# Out:
# /content
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/000035.jpg: 640x480 (no detections), 36.5ms
# Speed: 3.3ms preprocess, 36.5ms inference, 20.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/004.jpg
# Out:
# /content
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/004.jpg: 640x640 1 Glass, 16.2ms
# Speed: 2.9ms preprocess, 16.2ms inference, 538.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/005.jpg
# Out:
# /content
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/005.jpg: 640x640 1 Bin, 3 Metals, 16.2ms
# Speed: 2.9ms preprocess, 16.2ms inference, 550.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/006.jpg
# Out:
# /content
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/006.jpg: 640x640 2 Plastics, 16.2ms
# Speed: 3.0ms preprocess, 16.2ms inference, 519.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/000050.jpg
# Out:
# /content
# Ultralytics 8.3.66 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/000050.jpg: 640x480 (no detections), 60.0ms
# Speed: 5.3ms preprocess, 60.0ms inference, 40.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
